# %% [markdown]
# ## 数据读取

# %%
import pandas as pd

# 加载数据集
data_path = "lora_finetune.xlsx"
df = pd.read_excel(data_path)

# 查看数据前几行
print(df.head())

# 查看数据基本信息
print(df.info())
# Out:
#                                          instruction  \
# 0  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
# 1  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
# 2  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
# 3  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
# 4  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
#
#                                                input  \
# 0  最近的观察表明，动物类型：Dog 品种：Labrador 年龄：4岁 性别：Male 体重：...
# 1  最近的观察表明，动物类型：Cat 品种：Siamese 年龄：2岁 性别：Female 体重...
# 2  最近的观察表明，动物类型：Cow 品种：Holstein 年龄：3岁 性别：Female 体...
# 3  最近的观察表明，动物类型：Dog 品种：Beagle 年龄：1岁 性别：Male 体重：10...
# 4  最近的观察表明，动物类型：Cat 品种：Persian 年龄：5岁 性别：Male 体重：3...
#
#                                               output
# 0  拉布拉多犬出现发热、精神萎靡、食欲减退和呕吐等症状，且体温较高，符合细小病毒的典型症状，因此...
# 1  暹罗猫出现咳嗽、打喷嚏、眼鼻分泌物等症状，持续一周，这是上呼吸道感染的典型表现，因此患有上呼...
# 2  荷斯坦奶牛出现发热、鼻分泌物、呼吸困难和咳嗽等症状，且体温较高，这是口蹄疫的典型症状，因此患...
# 3  比格犬出现腹泻、呕吐、精神萎靡和食欲减退等症状，且持续时间较短，这是胃肠炎的典型表现，因此患...
# 4  波斯猫出现精神萎靡、食欲减退和皮肤病变等症状，持续两周，这是真菌感染的典型表现，因此患有真菌感染。
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instruction  200 non-null    object
#  1   input        200 non-null    object
#  2   output       200 non-null    object
# dtypes: object(3)
# memory usage: 4.8+ KB
# None

# %%
# 检查是否有缺失值
print(df.isnull().sum())

# 填充缺失值（如果有）
df.fillna({"instruction": "", "input": "", "output": ""}, inplace=True)

# 标准化文本格式
df["instruction"] = df["instruction"].str.strip()
df["input"] = df["input"].str.strip()
df["output"] = df["output"].str.strip()

# 再次检查数据
print(df.head())
# Out:
# instruction    0
# input          0
# output         0
# dtype: int64
#                                          instruction  \
# 0  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
# 1  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
# 2  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
# 3  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
# 4  您是经过培训的宠物个性化医疗保健代理，可以通过查找宠物各项生命指标，根据宠物的品种、年龄、性...
#
#                                                input  \
# 0  最近的观察表明，动物类型：Dog 品种：Labrador 年龄：4岁 性别：Male 体重：...
# 1  最近的观察表明，动物类型：Cat 品种：Siamese 年龄：2岁 性别：Female 体重...
# 2  最近的观察表明，动物类型：Cow 品种：Holstein 年龄：3岁 性别：Female 体...
# 3  最近的观察表明，动物类型：Dog 品种：Beagle 年龄：1岁 性别：Male 体重：10...
# 4  最近的观察表明，动物类型：Cat 品种：Persian 年龄：5岁 性别：Male 体重：3...
#
#                                               output
# 0  拉布拉多犬出现发热、精神萎靡、食欲减退和呕吐等症状，且体温较高，符合细小病毒的典型症状，因此...
# 1  暹罗猫出现咳嗽、打喷嚏、眼鼻分泌物等症状，持续一周，这是上呼吸道感染的典型表现，因此患有上呼...
# 2  荷斯坦奶牛出现发热、鼻分泌物、呼吸困难和咳嗽等症状，且体温较高，这是口蹄疫的典型症状，因此患...
# 3  比格犬出现腹泻、呕吐、精神萎靡和食欲减退等症状，且持续时间较短，这是胃肠炎的典型表现，因此患...
# 4  波斯猫出现精神萎靡、食欲减退和皮肤病变等症状，持续两周，这是真菌感染的典型表现，因此患有真菌感染。

# %%
from sklearn.model_selection import train_test_split

# 划分训练集和验证集
train_df, val_df = train_test_split(df, test_size=0.1, random_state=42)

# 保存为 JSON 文件（用于后续模型训练）
train_df.to_json("train_data.json", orient="records", lines=True)
val_df.to_json("val_data.json", orient="records", lines=True)

# %%
import subprocess
import os

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-1.5B-Instruct")
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2.5-1.5B-Instruct")

# %%
from peft import LoraConfig, get_peft_model

# 配置 LoRA
lora_config = LoraConfig(
    r=8,  # LoRA 的秩（rank），控制低秩矩阵的大小
    lora_alpha=32,  # 缩放因子
    target_modules=["q_proj", "v_proj"],  # 根据模型架构选择目标模块
    lora_dropout=0.1,  # Dropout 比例
    bias="none",  # 是否调整偏置
    task_type="CAUSAL_LM"  # 任务类型
)

# 将模型包装为 LoRA 模型
model = get_peft_model(model, lora_config)

# %% [markdown]
# ## 数据集tokenization

# %%
# 导入必要的库
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, DataCollatorForSeq2Seq, TrainingArguments, Trainer
from peft import LoraConfig, get_peft_model

# 加载 JSON 数据集
train_dataset = load_dataset("json", data_files="train_data.json", split="train")
val_dataset = load_dataset("json", data_files="val_data.json", split="train")

# 加载预训练模型和分词器
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-1.5B-Instruct")
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2.5-1.5B-Instruct")

# 配置 LoRA
lora_config = LoraConfig(
    r=4,  # LoRA 的秩（rank），控制低秩矩阵的大小
    lora_alpha=16,  # 缩放因子
    target_modules=["q_proj", "v_proj"],  # 根据模型架构选择目标模块
    lora_dropout=0.1,  # Dropout 比例
    bias="none",  # 是否调整偏置
    task_type="CAUSAL_LM"  # 任务类型
)

# 将模型包装为 LoRA 模型
model = get_peft_model(model, lora_config)

def tokenize_function(examples):
    # 确保 inputs 和 outputs 是字符串列表
    inputs = [str(instr) + " " + str(inp) for instr, inp in zip(examples["instruction"], examples["input"])]
    outputs = [str(out) for out in examples["output"]]
    
    # 对输入和输出进行编码
    model_inputs = tokenizer(inputs, max_length=512, truncation=True, padding="max_length")
    labels = tokenizer(outputs, max_length=128, truncation=True, padding="max_length")
    
    # 将标签添加到模型输入中
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# 对数据集进行 Tokenization
tokenized_train = train_dataset.map(tokenize_function, batched=True)
tokenized_val = val_dataset.map(tokenize_function, batched=True)

# 使用 DataCollator 进行动态填充
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    padding="max_length",
    max_length=512,  # 确保与 tokenize_function 中的 max_length 一致
    label_pad_token_id=-100  # 忽略填充部分的损失计算
)
# Out:
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]

# %%
# 定义训练参数
training_args = TrainingArguments(
    output_dir="./results_lora",  # 输出目录
    eval_strategy="epoch",  # 每个 epoch 进行一次评估
    learning_rate=3e-5,  # 学习率
    per_device_train_batch_size=1,  # 训练时每个设备的批量大小
    per_device_eval_batch_size=2,  # 评估时每个设备的批量大小
    num_train_epochs=10,  # 训练轮数
    weight_decay=0.01,  # 权重衰减
    save_strategy="epoch",  # 每个 epoch 保存一次模型
    logging_dir="./logs",  # 日志目录
    logging_steps=10,  # 每 10 步记录一次日志
    fp16=True,  # 使用混合精度训练（需要支持 GPU）
    gradient_accumulation_steps=2,  # 梯度累积步数
)

# 初始化 Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_val,
    tokenizer=tokenizer,
    data_collator=data_collator
)

import torch
torch.cuda.empty_cache()

# 开始训练
trainer.train()
# Out:
# /tmp/ipykernel_1260/1957446796.py:18: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='900' max='900' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [900/900 04:04, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.175800</td>
#       <td>3.096762</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.192500</td>
#       <td>2.328511</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.981800</td>
#       <td>2.114756</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.825300</td>
#       <td>2.004312</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.733600</td>
#       <td>1.913601</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.668600</td>
#       <td>1.853724</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.764700</td>
#       <td>1.806363</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.619300</td>
#       <td>1.778624</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.663500</td>
#       <td>1.765409</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.729900</td>
#       <td>1.758090</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=900, training_loss=2.208130193286472, metrics={'train_runtime': 244.6314, 'train_samples_per_second': 7.358, 'train_steps_per_second': 3.679, 'total_flos': 7248671775129600.0, 'train_loss': 2.208130193286472, 'epoch': 10.0})

# %%
# 保存微调后的模型
model.save_pretrained("./results_lora")
tokenizer.save_pretrained("./results_lora")
# Out:
# ('./results_lora/tokenizer_config.json',
#  './results_lora/special_tokens_map.json',
#  './results_lora/vocab.json',
#  './results_lora/merges.txt',
#  './results_lora/added_tokens.json',
#  './results_lora/tokenizer.json')

# %%
def generate_health_advice(instruction, input_text):
    # 将指令和输入拼接成完整输入
    full_input = f"{instruction} 输入：{input_text}"
    
    # 对输入进行编码
    inputs = tokenizer(
        full_input,
        return_tensors="pt",
        max_length=512,
        truncation=True,
        padding="max_length"
    )
    
    # 确保输入张量在正确的设备上
    inputs = {k: v.to(model.device) for k, v in inputs.items()}
    
    # 使用 num_beams > 1 并移除 early_stopping
    outputs = model.generate(
        inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=512,  # 增加最大生成长度
        num_beams=4,         # 使用束搜索
        do_sample=True,      # 启用采样
        temperature=0.7,     # 控制随机性
        top_p=0.9,           # 核采样
        no_repeat_ngram_size=3,
        pad_token_id=tokenizer.eos_token_id
    )
    
    # 解码生成的 token
    advice = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    # 提取生成的实际建议部分
    advice = advice.replace(full_input, "").strip()
    return advice

# 示例输入
example_instruction = (
    "您是经过培训的宠物个性化医疗保健代理，可以根据宠物的症状和体征，提供详细的诊断建议和护理指南。"
    "请分析以下输入中的症状，列出可能的原因，并给出具体的处理步骤和注意事项。"
)
example_input = (
    "最近的观察表明，动物类型:Dog 品种:Labrador 年龄:4岁 性别:Male 体重:25.0公斤, "
    "症状1:Fever 症状2:Lethargy 症状3:Appetite Loss 症状4:Vomiting 持续时间:3 days。"
    "食欲减退:Yes 呕吐:Yes 腹泻:No 咳嗽:No 呼吸困难:No 关节疼痛:No 皮肤病变:No 鼻分泌物:No 眼分泌物:No。"
    "体温:39.5°C 心率:120。"
    "我家狗狗一直吃不下东西。"
    "我的狗狗一直在颤抖，怎么办？"
)

# 分割输入文本为句子
sentences = [s.strip() for s in re.split(r'[。！？]', example_input) if s.strip()]

# 逐句生成健康建议
results = []
for sentence in sentences:
    advice = generate_health_advice(example_instruction, sentence)
    results.append((sentence, advice))

# 输出结果
for i, (sentence, advice) in enumerate(results):
    print(f"句子 {i+1}: {sentence}")
    print(f"健康建议: {advice}\n")
# Out:
# 句子 1: 最近的观察表明，动物类型:Dog 品种:Labrador 年龄:4岁 性别:Male 体重:25.0公斤, 症状1:Fever 症状2:Lethargy 症状3:Appetite Loss 症状4:Vomiting 持续时间:3 days
# 健康建议: 。
#
# 句子 2: 食欲减退:Yes 呕吐:Yes 腹泻:No 咳嗽:No 呼吸困难:No 关节疼痛:No 皮肤病变:No 鼻分泌物:No 眼分泌物:No
# 健康建议: 根据输入症状，可能的原因包括：
#
# 1. 消化系统疾病：如胃炎、胃溃疡、肠梗阻等
# 2. �寄生虫感染：如蛔虫、钩虫等
# 3. �肺部疾病：例如肺炎、肺气肿等
# 4. 心脏疾病
# 5. �免疫系统疾病
# 6. �神经疾病
# 7. �内分泌疾病
# 8. �代谢疾病
# 9. �关节疾病
# 10. �皮肤疾病
#
# 处理步骤：
# 1. 详细询问病史，包括症状出现的时间、严重程度、伴随症状等。
# 2. 进行体格检查，包括体温、脉搏、呼吸、血压等。
# 3. 实验室检查：包括血常规、尿常规、生化检查等。
# 4. 影像学检查：如X光、超声、CT、MRI等。
# 5. 物理检查：检查关节、皮肤、鼻分泌物、眼分泌物等。
# 6. 根据检查结果，制定治疗方案，包括药物治疗、手术治疗、物理治疗等。
# 7. 定期复查，监测病情变化。
#
# 注意事项：在治疗过程中，要密切观察病情变化，及时调整治疗方案。同时，要保持良好的饮食和生活习惯，增强免疫力，预防疾病的发生。
#
# 句子 3: 体温:39.5°C 心率:120
# 健康建议: 咳嗽
#
# 根据输入的症状，可能的原因包括肺炎、支气管炎、肺部感染等。具体处理步骤包括：
#
# 1. 诊断：需要进一步的检查，如胸部X光、血液检查等，以确定病因。
#
# 2. 护理：保持宠物安静，避免剧烈运动，提供充足的水分和营养。
#
# 3. 治疗：根据诊断结果，可能需要使用抗生素、抗炎药等药物。注意观察宠物的反应，及时调整治疗方案。
#
# 4. �隔离：将宠物隔离，避免传染给其他宠物或人。
#
# 注意事项：在治疗期间，需要定期监测宠物的体温、心率、呼吸等，及时发现并处理并发症。同时，注意宠物的饮食和休息，避免过度疲劳。如果宠物出现呼吸困难、咳嗽加重等症状，需要及时就医。
#
# 句子 4: 我家狗狗一直吃不下东西
# 健康建议: 发热
#
# 可能的原因：
#
# 1. �肠胃炎：病毒或细菌感染导致的胃肠道炎症，引起呕吐、腹泻、发热等症状。
#
# 2. �食物中毒：食用了不新鲜或变质的食物，导致胃肠道不适，引起发热、呕吐等症状。
#
# 3. �肠虫病：寄生虫侵入肠道，引起肠炎，导致发热、腹泻等症状。
#
# 4. �肺部感染：肺炎、支气管炎等肺部疾病，导致呼吸困难、发热、咳嗽等症状。
#
# 5. �心脏疾病：心肌炎、心包炎等心脏疾病，引起心力衰竭、呼吸困难等症状。
#
# 6. �肝脏疾病：肝炎、肝硬化等肝病，引起黄疸、腹水等症状。
#
# 7. �肾脏疾病：肾炎、肾功能衰竭等肾病，导致尿量减少、水肿等症状。
#
# 处理步骤：
# 1. 就医：及时带宠物到兽医处就诊，进行详细检查和诊断。
# 2. 休息：让宠物充分休息，避免剧烈运动。
# 3. �消炎：使用消炎药物，减轻炎症反应。
# 4. 补液：使用补液药物，补充体内水分和电解质。
# 5. 对症治疗：根据症状使用对症治疗药物，如止吐药、止咳药等。
# 6. 注意事项：注意观察宠物的病情变化，如有异常及时就医。
#
# 句子 5: 我的狗狗一直在颤抖，怎么办
# 健康建议: Assistant: 1. �可能的原因：低血糖、甲状腺功能亢进、心脏病、神经系统疾病等。 2. 具体处理步骤： 1) 咨询兽医进行详细检查和诊断； 2) 根据兽医的建议进行治疗； 3) 注意饮食和休息。 3. 注意事项：注意观察狗狗的其他症状，如呕吐、腹泻、呼吸困难等，及时咨询兽医。
